# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import scipy.signal as signal
import os
import torch
from torch import nn
import sklearn

fn = os.path.join('..', 'data', 'BP_data.pkl')
df = pd.read_pickle(fn)
df = df[df['DiastolicP']>30]  # trow out outlier
df = df.reset_index(drop = True)

print(df)
print(df.columns)
# Out:
#     SubjectID Condition  Age Gender  Height  Weight  SystolicP  DiastolicP  \
# 0    c010510d        BN   63      M   170.0    66.1      161.0        82.5
# 1    c010510d        BN   63      M   170.0    66.1      162.2        82.8
# 2    c010510d        AN   63      M   170.0    66.1      155.2        80.3
# 3    c010510d        AN   63      M   170.0    66.1      157.3        79.3
# 4    c010610d        BN   49      M   175.2    82.4      129.5        72.6
# ..        ...       ...  ...    ...     ...     ...        ...         ...
# 188  c121609d        BN   84      M   163.0    50.0      140.1        65.4
# 189  c121609d        AN   84      M   163.0    50.0      133.8        64.2
# 190  c122309d        BN   65      F   154.2    62.6      139.6        69.9
# 191  c122309d        BN   65      F   154.2    62.6      140.2        69.3
# 192  c122309d        AN   65      F   154.2    62.6      139.7        72.7
#
#      MeanP                                              CuffP  \
# 0    113.5  [78.0799, 79.37099, 80.66207, 81.95315, 83.244...
# 1    113.4  [64.32275, 65.56285, 66.802956, 68.04306, 69.2...
# 2    106.8  [63.112442, 64.64711, 66.181786, 67.71645, 69....
# 3    106.9  [62.98758, 64.516235, 66.0449, 67.573555, 69.1...
# 4     96.7  [68.72236, 69.447624, 70.17289, 70.89816, 71.6...
# ..     ...                                                ...
# 188   91.7  [68.6797, 69.41152, 70.14333, 70.87515, 71.606...
# 189   87.0  [58.49573, 59.325638, 60.155544, 60.98545, 61....
# 190  100.1  [75.1058, 75.995926, 76.886055, 77.77618, 78.6...
# 191  100.2  [63.414898, 64.367226, 65.31956, 66.27189, 67....
# 192   96.2  [63.80237, 64.66382, 65.52526, 66.38671, 67.24...
#
#                                              Amplitude  \
# 0    [3.8775666, 3.9830372, 4.088508, 4.206781, 4.3...
# 1    [2.310238, 2.3567293, 2.4032207, 2.4376183, 2....
# 2    [3.0087252, 3.1160161, 3.2061627, 3.2970684, 3...
# 3    [2.9945104, 3.0730634, 3.1505506, 3.2228527, 3...
# 4    [1.5772955, 1.6235869, 1.6698784, 1.7161697, 1...
# ..                                                 ...
# 188  [3.6818395, 3.7508392, 3.8198392, 3.888839, 3....
# 189  [3.498915, 3.576125, 3.6533349, 3.7305448, 3.8...
# 190  [1.851946, 1.8663046, 1.8806632, 1.8950218, 1....
# 191  [1.103094, 1.1245613, 1.1460286, 1.167496, 1.1...
# 192  [1.3227572, 1.344889, 1.3670208, 1.3988788, 1....
#
#                                                   Area  \
# 0    [1.3602165, 1.4028324, 1.4454483, 1.4912764, 1...
# 1    [0.76856595, 0.7840019, 0.7994379, 0.8184511, ...
# 2    [0.94789666, 0.99014, 1.0260116, 1.0632582, 1....
# 3    [0.95734394, 0.9881888, 1.0195315, 1.0532969, ...
# 4    [0.70405054, 0.7245042, 0.7449578, 0.76541144,...
# ..                                                 ...
# 188  [1.288412, 1.3111385, 1.333865, 1.3565916, 1.3...
# 189  [1.1944417, 1.2207044, 1.2469672, 1.27323, 1.2...
# 190  [0.74407285, 0.75344163, 0.76281047, 0.7721792...
# 191  [0.3880808, 0.40249988, 0.41691896, 0.431338, ...
# 192  [0.34793875, 0.34874594, 0.34955317, 0.3575320...
#
#                                      brachial_waveform  \
# 0    [82.8542436432542, 82.7778210948817, 82.754450...
# 1    [82.4515647094317, 82.3442482056791, 82.284497...
# 2    [83.7632735473351, 83.7040098171201, 83.687055...
# 3    [79.4237058246234, 79.3685111330707, 79.359185...
# 4    [72.8077773614127, 72.74497320349, 72.72640745...
# ..                                                 ...
# 188  [65.2777840033456, 65.2184252261065, 65.187172...
# 189  [65.5142789334821, 65.3841912814326, 65.248654...
# 190  [69.0724485709897, 69.007510590418, 68.9792880...
# 191  [67.0430461454453, 66.9852009383432, 66.969284...
# 192  [79.71912248862, 79.6552325660539, 79.58737143...
#
#                                       dc_cuff_pressure  \
# 0    [209.041015997764, 209.032015648728, 209.02302...
# 1    [190.506065905155, 190.495696731319, 190.48533...
# 2    [218.221239413274, 218.211945641946, 218.20265...
# 3    [217.633582724921, 217.624237974048, 217.61489...
# 4    [143.647988301787, 143.638153575861, 143.62832...
# ..                                                 ...
# 188  [148.178062663992, 148.167004485163, 148.15594...
# 189  [144.298300283927, 144.289331054801, 144.28036...
# 190  [167.973080476154, 167.961873929717, 167.95066...
# 191  [161.648908349982, 161.639492149518, 161.63007...
# 192  [152.178655691958, 152.170340655723, 152.16202...
#
#                             cuff_pressure_oscillations
# 0    [-0.270020377911717, -0.258716206161382, -0.24...
# 1    [-0.304499470621906, -0.29304664510834, -0.280...
# 2    [-0.167579011732968, -0.154982364778615, -0.14...
# 3    [-0.378898090241766, -0.367338825134386, -0.35...
# 4    [-0.0572602266012176, -0.0512452446370652, -0....
# ..                                                 ...
# 188  [-0.213506797813109, -0.20762145565671, -0.201...
# 189  [-0.239908632417597, -0.235739763384284, -0.23...
# 190  [-0.14558156605165, -0.144270274147579, -0.142...
# 191  [-0.126711053686341, -0.125173045421664, -0.12...
# 192  [-0.248173663837143, -0.253125336717772, -0.25...
#
# [193 rows x 15 columns]
# Index(['SubjectID', 'Condition', 'Age', 'Gender', 'Height', 'Weight',
#        'SystolicP', 'DiastolicP', 'MeanP', 'CuffP', 'Amplitude', 'Area',
#        'brachial_waveform', 'dc_cuff_pressure', 'cuff_pressure_oscillations'],
#       dtype='object')

# %%
def butter_filter(data, cutoff, fs, order=5, btype = 'low'):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = signal.butter(order, normal_cutoff, btype=btype, analog=False)
    y = signal.filtfilt(b, a, data, method='gust' )
    return y

def hilbert_mag(x):
    signal2 = np.concatenate((x[::-1], x, x[::-1]))
    analytic_signal2 = signal.hilbert(signal2)
    amplitude_envelope = np.abs(analytic_signal2[len(x):2*len(x)])
    return amplitude_envelope

def moving_average(a, n=1000):
    # ret = np.cumsum(a, dtype=float)
    # ret[n:] = ret[n:] - ret[:-n]
    # return ret[n - 1:] / n

    x = np.linspace(-3, 3, n)
    v = np.exp(-(x/1)**2/2)
    #v = np.ones(n)

    y = np.convolve(a, v, mode='same')/np.sum(v)
    return y


if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
    device = 'cuda'
else:
    print("No GPU available. Training will run on CPU.")
    device = 'cpu'
# Out:
# GPU: NVIDIA GeForce RTX 3070 is available.

# %%
for i in range(3):

    fig, ax = plt.subplots(3, 1)

    fig.set_size_inches(15, 5)

    t = np.arange(0, len(df.loc[i, 'dc_cuff_pressure'])*1/500, 1/500)

    ax[0].plot(t, df.loc[i, 'dc_cuff_pressure'])
    ax[0].plot(t, df.loc[i, 'brachial_waveform'])
    ax[0].set_xlim(0, t[-1])
    ax2 = ax[0].twinx()
    ax2.plot(t, df.loc[i, 'cuff_pressure_oscillations'])

    f_spec, t_spec, Sxx = signal.spectrogram(df.loc[i, 'cuff_pressure_oscillations'], fs = 500, nperseg = 2000, noverlap=1950)

    ax[1].pcolormesh(t_spec, f_spec, Sxx/np.max(Sxx, axis = 1, keepdims=True), shading='auto')
    ax[1].set_ylim(0, 4)

    I = f_spec<4
    Sxx = Sxx[I, :]
    Sxx = Sxx/np.max(Sxx, axis = 1, keepdims=True)
    ax[2].plot(Sxx.T)

# %%
seq_length = 100
N_samples = len(df)
N_features = 3
N_targets = 3

XX = np.zeros((N_samples, seq_length, N_features), dtype = np.float32)
YY = np.zeros((N_samples, 1, N_targets), dtype = np.float32)

# def make_spectrogram(x):
#     f_spec, t_spec, Sxx = signal.spectrogram(df.loc[i, 'cuff_pressure_oscillations'], fs = 500, nperseg = 2000, noverlap=1950)
#     I = np.logical_and(f_spec<4, f_spec>0)
#     Sxx = Sxx[I, :]
#     Sxx = Sxx/np.max(Sxx, axis = 1, keepdims=True)
#     f_spec =f_spec[I]
#     print(Sxx.shape)
#     return f_spec, t_spec, Sxx



for i, idx in enumerate(df.index):
  
  
    dc = df.at[idx, 'dc_cuff_pressure']
    SP = df.at[idx, 'SystolicP']
    DP = df.at[idx, 'DiastolicP']
    MP = df.at[idx, 'MeanP']

    XX[i, :, 0] = df.at[idx, 'CuffP']
    XX[i, :, 1] = df.at[idx, 'Amplitude']
    XX[i, :, 2] = df.at[idx, 'Area']

    YY[i, 0, 0] = MP 
    YY[i, 0, 1] = DP
    YY[i, 0, 2] = SP

# %%
def normaize_data(XX, reverse = False, Xnorm = (0, 1)):
    
    if reverse == True:
        XX = XX*(Xnorm[1]-Xnorm[0]) + Xnorm[0]

    else:
        minX = np.min(XX, axis = (0, 1), keepdims=True)
        maxX = np.max(XX, axis = (0, 1), keepdims=True)
        Xnorm = (minX, maxX)
        XX = (XX-Xnorm[0])/(Xnorm[1]-Xnorm[0])


    return XX, Xnorm

# %%
N_test = 30  # dont duplicate test data into training


def gen_synthetic_data(XX, YY, mag = 2.5, multiple = 2, N_test = N_test):
    print(XX.shape, YY.shape)
    for j in range(multiple):
        XX2 = XX[N_test:,:,:].copy()
        YY2 = YY[N_test:,:,:].copy()

        rand_offset = 2*mag*(np.random.rand(XX2.shape[0], 1, 1)-.5)

        XX2[:, :, [0]] = XX2[:, :, [0]] + rand_offset
        YY2[:, :, :] = YY2[:, :, :] + rand_offset

        XX = np.concatenate([XX, XX2], axis = 0)
        YY = np.concatenate([YY, YY2], axis = 0)
        print(XX.shape, YY.shape)
    return XX, YY


XX, YY = gen_synthetic_data(XX, YY)
# Out:
# (193, 100, 3) (193, 1, 3)
# (356, 100, 3) (356, 1, 3)
# (682, 100, 3) (682, 1, 3)

# %%
XX, Xnorm = normaize_data(XX)
YY, Ynorm = normaize_data(YY)

print(np.min(XX), np.max(XX))
# Out:
# 0.0 1.0

# %%
XX = torch.tensor(XX, device=device)
YY = torch.tensor(YY, device=device)

print(XX.shape, YY.shape)
# Out:
# torch.Size([682, 100, 3]) torch.Size([682, 1, 3])

# %%
I_train = np.full(XX.shape[0], True)
I_train[:N_test] = False

XX_test = XX[~I_train, :, :]
XX_train = XX[I_train, :, :]
YY_test = YY[~I_train, :, :]
YY_train = YY[I_train, :, :]

print(XX_train.shape, YY_train.shape)
print(YY_test.shape, YY_test.shape)
# Out:
# torch.Size([652, 100, 3]) torch.Size([652, 1, 3])
# torch.Size([30, 1, 3]) torch.Size([30, 1, 3])

# %%
class neural_network(nn.Module):
    def __init__(self, input_size , output_size, hidden_size = 75, num_layers = 4):
        super(neural_network,self).__init__()
        self.fc0 = nn.Linear(in_features=input_size,out_features=5*input_size)
        self.lstm = nn.LSTM(input_size=5*input_size,hidden_size=hidden_size,num_layers=num_layers,batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(in_features=2*hidden_size,out_features=output_size)
        self.dropout = nn.Dropout(p = .1)

    def forward(self,x):
        output = x
        output = self.fc0(output)
        output = torch.relu(output)
        output = self.dropout(output)
        output,_status = self.lstm(output)
        output = output[:,[-1],:]
        output = self.dropout(output)
        output = self.fc1(torch.relu(output))
        return output

# %%
model = neural_network(input_size = N_features, output_size = N_targets)
model.to(device)
model.train()


optimizer = torch.optim.AdamW(model.parameters(),lr=0.01)
loss = torch.nn.MSELoss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min',  factor=0.9, patience=100)

epochs = 10000

losses_train = []
losses_test = []
no_improvement_count = 0
loss_to_beat = 999999.0


for i in range(epochs):
        model.train()
        optimizer.zero_grad() 

        YY_pred_train = model(XX_train)

        loss_train = loss(YY_pred_train,YY_train)
        loss_train.backward()
        optimizer.step()

        with torch.no_grad():
                model.eval()
                YY_pred_test = model(XX_test)
                loss_test = loss(YY_pred_test,YY_test)
                scheduler.step(loss_test)

        if i%10 ==0:
                print(f'{i}, train loss = {loss_train:.4e}, test loss = {loss_test:.4e}, no improvement for epochs = {no_improvement_count}, lr = {scheduler.get_last_lr()[0]:.2e}')
        
        loss_train = loss_train.cpu().detach().numpy()
        loss_test = loss_test.cpu().detach().numpy()

        if loss_test < loss_to_beat:
                loss_to_beat = loss_test
                no_improvement_count = 0
        else:
                no_improvement_count = no_improvement_count+1

        if no_improvement_count > 1000:  # early stopping
                print('early stopping activated')
                break

        losses_train.append(loss_train)
        losses_test.append(loss_test)
# Out:
# 0, train loss = 1.9116e-01, test loss = 8.6356e-02, no improvement for epochs = 0, lr = 1.00e-02
# 10, train loss = 4.7953e-02, test loss = 3.4684e-02, no improvement for epochs = 1, lr = 1.00e-02
# 20, train loss = 4.1353e-02, test loss = 3.1395e-02, no improvement for epochs = 11, lr = 1.00e-02
# 30, train loss = 4.0375e-02, test loss = 3.2554e-02, no improvement for epochs = 21, lr = 1.00e-02
# 40, train loss = 4.0803e-02, test loss = 3.2634e-02, no improvement for epochs = 31, lr = 1.00e-02
# 50, train loss = 4.0606e-02, test loss = 3.0478e-02, no improvement for epochs = 41, lr = 1.00e-02
# 60, train loss = 3.8696e-02, test loss = 2.1681e-02, no improvement for epochs = 1, lr = 1.00e-02
# 70, train loss = 3.0128e-02, test loss = 1.8267e-02, no improvement for epochs = 5, lr = 1.00e-02
# 80, train loss = 2.9859e-02, test loss = 1.9788e-02, no improvement for epochs = 6, lr = 1.00e-02
# 90, train loss = 2.9827e-02, test loss = 2.1013e-02, no improvement for epochs = 16, lr = 1.00e-02
# 100, train loss = 2.9096e-02, test loss = 1.9674e-02, no improvement for epochs = 26, lr = 1.00e-02
# 110, train loss = 2.8845e-02, test loss = 1.9942e-02, no improvement for epochs = 36, lr = 1.00e-02
# 120, train loss = 2.9249e-02, test loss = 2.0544e-02, no improvement for epochs = 8, lr = 1.00e-02
# 130, train loss = 2.8307e-02, test loss = 1.8991e-02, no improvement for epochs = 18, lr = 1.00e-02
# 140, train loss = 2.7608e-02, test loss = 2.1401e-02, no improvement for epochs = 28, lr = 1.00e-02
# 150, train loss = 2.7359e-02, test loss = 2.0306e-02, no improvement for epochs = 38, lr = 1.00e-02
# 160, train loss = 2.7203e-02, test loss = 1.9833e-02, no improvement for epochs = 48, lr = 1.00e-02
# 170, train loss = 2.7615e-02, test loss = 1.9581e-02, no improvement for epochs = 58, lr = 1.00e-02
# 180, train loss = 2.7146e-02, test loss = 1.7812e-02, no improvement for epochs = 68, lr = 1.00e-02
# 190, train loss = 2.6269e-02, test loss = 1.7486e-02, no improvement for epochs = 78, lr = 1.00e-02
# 200, train loss = 2.6840e-02, test loss = 1.7947e-02, no improvement for epochs = 88, lr = 1.00e-02
# 210, train loss = 2.6959e-02, test loss = 1.8978e-02, no improvement for epochs = 98, lr = 1.00e-02
# 220, train loss = 2.6262e-02, test loss = 2.3987e-02, no improvement for epochs = 108, lr = 9.00e-03
# 230, train loss = 2.3488e-02, test loss = 2.2216e-02, no improvement for epochs = 118, lr = 9.00e-03
# 240, train loss = 2.4498e-02, test loss = 2.0272e-02, no improvement for epochs = 128, lr = 9.00e-03
# 250, train loss = 2.4509e-02, test loss = 1.9178e-02, no improvement for epochs = 138, lr = 9.00e-03
# 260, train loss = 2.3788e-02, test loss = 1.7494e-02, no improvement for epochs = 148, lr = 9.00e-03
# 270, train loss = 2.3168e-02, test loss = 2.0090e-02, no improvement for epochs = 158, lr = 9.00e-03
# 280, train loss = 2.1463e-02, test loss = 1.8944e-02, no improvement for epochs = 168, lr = 9.00e-03
# 290, train loss = 2.2780e-02, test loss = 2.0467e-02, no improvement for epochs = 7, lr = 9.00e-03
# 300, train loss = 2.2045e-02, test loss = 1.6302e-02, no improvement for epochs = 17, lr = 9.00e-03
# 310, train loss = 2.1660e-02, test loss = 1.7030e-02, no improvement for epochs = 8, lr = 9.00e-03
# 320, train loss = 1.8853e-02, test loss = 1.8140e-02, no improvement for epochs = 18, lr = 9.00e-03
# 330, train loss = 1.8003e-02, test loss = 2.1129e-02, no improvement for epochs = 28, lr = 9.00e-03
# 340, train loss = 2.4835e-02, test loss = 2.2557e-02, no improvement for epochs = 38, lr = 9.00e-03
# 350, train loss = 1.9862e-02, test loss = 2.2071e-02, no improvement for epochs = 48, lr = 9.00e-03
# 360, train loss = 1.9239e-02, test loss = 1.8385e-02, no improvement for epochs = 58, lr = 9.00e-03
# 370, train loss = 1.8045e-02, test loss = 1.7392e-02, no improvement for epochs = 68, lr = 9.00e-03
# 380, train loss = 1.7484e-02, test loss = 1.6546e-02, no improvement for epochs = 78, lr = 9.00e-03
# 390, train loss = 1.7566e-02, test loss = 1.8270e-02, no improvement for epochs = 88, lr = 9.00e-03
# 400, train loss = 1.5301e-02, test loss = 1.6340e-02, no improvement for epochs = 98, lr = 9.00e-03
# 410, train loss = 1.5880e-02, test loss = 1.8624e-02, no improvement for epochs = 108, lr = 8.10e-03
# 420, train loss = 1.3474e-02, test loss = 1.9172e-02, no improvement for epochs = 118, lr = 8.10e-03
# 430, train loss = 1.5177e-02, test loss = 1.8284e-02, no improvement for epochs = 128, lr = 8.10e-03
# 440, train loss = 1.2148e-02, test loss = 2.0448e-02, no improvement for epochs = 138, lr = 8.10e-03
# 450, train loss = 1.2539e-02, test loss = 1.9649e-02, no improvement for epochs = 148, lr = 8.10e-03
# 460, train loss = 1.1526e-02, test loss = 1.9524e-02, no improvement for epochs = 158, lr = 8.10e-03
# 470, train loss = 1.0477e-02, test loss = 2.2994e-02, no improvement for epochs = 168, lr = 8.10e-03
# 480, train loss = 8.8012e-03, test loss = 2.2172e-02, no improvement for epochs = 178, lr = 8.10e-03
# 490, train loss = 7.9284e-03, test loss = 2.3027e-02, no improvement for epochs = 188, lr = 8.10e-03
# 500, train loss = 8.0202e-03, test loss = 2.1176e-02, no improvement for epochs = 198, lr = 8.10e-03
# 510, train loss = 8.4470e-03, test loss = 1.9494e-02, no improvement for epochs = 208, lr = 7.29e-03
# 520, train loss = 1.0528e-02, test loss = 2.0771e-02, no improvement for epochs = 218, lr = 7.29e-03
# 530, train loss = 7.0471e-03, test loss = 2.0489e-02, no improvement for epochs = 228, lr = 7.29e-03
# 540, train loss = 6.8719e-03, test loss = 2.1395e-02, no improvement for epochs = 238, lr = 7.29e-03
# 550, train loss = 6.4749e-03, test loss = 1.9629e-02, no improvement for epochs = 248, lr = 7.29e-03
# 560, train loss = 5.0492e-03, test loss = 2.0007e-02, no improvement for epochs = 258, lr = 7.29e-03
# 570, train loss = 4.8156e-03, test loss = 1.8917e-02, no improvement for epochs = 268, lr = 7.29e-03
# 580, train loss = 7.4507e-03, test loss = 1.7336e-02, no improvement for epochs = 278, lr = 7.29e-03
# 590, train loss = 5.4372e-03, test loss = 1.7343e-02, no improvement for epochs = 288, lr = 7.29e-03
# 600, train loss = 5.7645e-03, test loss = 2.1901e-02, no improvement for epochs = 298, lr = 7.29e-03
# 610, train loss = 3.7464e-03, test loss = 2.1981e-02, no improvement for epochs = 308, lr = 6.56e-03
# 620, train loss = 4.4769e-03, test loss = 2.0886e-02, no improvement for epochs = 318, lr = 6.56e-03
# 630, train loss = 2.8578e-03, test loss = 2.1187e-02, no improvement for epochs = 328, lr = 6.56e-03
# 640, train loss = 5.4545e-03, test loss = 2.0913e-02, no improvement for epochs = 338, lr = 6.56e-03
# 650, train loss = 3.8433e-03, test loss = 1.9145e-02, no improvement for epochs = 348, lr = 6.56e-03
# 660, train loss = 3.0966e-03, test loss = 1.9130e-02, no improvement for epochs = 358, lr = 6.56e-03
# 670, train loss = 3.7834e-03, test loss = 1.8928e-02, no improvement for epochs = 368, lr = 6.56e-03
# 680, train loss = 3.1011e-03, test loss = 1.6973e-02, no improvement for epochs = 378, lr = 6.56e-03
# 690, train loss = 3.1684e-03, test loss = 1.8795e-02, no improvement for epochs = 388, lr = 6.56e-03
# 700, train loss = 2.1081e-03, test loss = 1.8464e-02, no improvement for epochs = 398, lr = 6.56e-03
# 710, train loss = 3.6801e-03, test loss = 1.9575e-02, no improvement for epochs = 408, lr = 5.90e-03
# 720, train loss = 3.0167e-03, test loss = 1.9783e-02, no improvement for epochs = 418, lr = 5.90e-03
# 730, train loss = 3.4237e-03, test loss = 2.2342e-02, no improvement for epochs = 428, lr = 5.90e-03
# 740, train loss = 2.7457e-03, test loss = 1.9693e-02, no improvement for epochs = 438, lr = 5.90e-03
# 750, train loss = 1.9813e-03, test loss = 1.9135e-02, no improvement for epochs = 448, lr = 5.90e-03
# 760, train loss = 3.1430e-03, test loss = 2.0443e-02, no improvement for epochs = 458, lr = 5.90e-03
# 770, train loss = 2.1172e-03, test loss = 2.0638e-02, no improvement for epochs = 468, lr = 5.90e-03
# 780, train loss = 2.3043e-03, test loss = 2.0795e-02, no improvement for epochs = 478, lr = 5.90e-03
# 790, train loss = 2.6932e-03, test loss = 1.9729e-02, no improvement for epochs = 488, lr = 5.90e-03
# 800, train loss = 2.9299e-03, test loss = 1.9685e-02, no improvement for epochs = 498, lr = 5.90e-03
# 810, train loss = 1.5519e-03, test loss = 2.1242e-02, no improvement for epochs = 508, lr = 5.31e-03
# 820, train loss = 1.5077e-03, test loss = 1.9701e-02, no improvement for epochs = 518, lr = 5.31e-03
# 830, train loss = 2.0318e-03, test loss = 2.0927e-02, no improvement for epochs = 528, lr = 5.31e-03
# 840, train loss = 1.6062e-03, test loss = 2.1621e-02, no improvement for epochs = 538, lr = 5.31e-03
# 850, train loss = 1.3582e-03, test loss = 1.9843e-02, no improvement for epochs = 548, lr = 5.31e-03
# 860, train loss = 1.2880e-03, test loss = 2.1010e-02, no improvement for epochs = 558, lr = 5.31e-03
# 870, train loss = 1.6139e-03, test loss = 1.9887e-02, no improvement for epochs = 568, lr = 5.31e-03
# 880, train loss = 1.3823e-03, test loss = 2.0481e-02, no improvement for epochs = 578, lr = 5.31e-03
# 890, train loss = 1.1253e-03, test loss = 1.9072e-02, no improvement for epochs = 588, lr = 5.31e-03
# 900, train loss = 1.3006e-03, test loss = 2.0024e-02, no improvement for epochs = 598, lr = 5.31e-03
# 910, train loss = 9.6129e-04, test loss = 2.0031e-02, no improvement for epochs = 608, lr = 4.78e-03
# 920, train loss = 1.0985e-03, test loss = 2.0434e-02, no improvement for epochs = 618, lr = 4.78e-03
# 930, train loss = 1.4444e-03, test loss = 2.1341e-02, no improvement for epochs = 628, lr = 4.78e-03
# 940, train loss = 1.1635e-03, test loss = 2.1062e-02, no improvement for epochs = 638, lr = 4.78e-03
# 950, train loss = 1.0348e-03, test loss = 2.0429e-02, no improvement for epochs = 648, lr = 4.78e-03
# 960, train loss = 1.0378e-03, test loss = 2.0159e-02, no improvement for epochs = 658, lr = 4.78e-03
# 970, train loss = 1.0337e-03, test loss = 2.1065e-02, no improvement for epochs = 668, lr = 4.78e-03
# 980, train loss = 9.1096e-04, test loss = 2.0381e-02, no improvement for epochs = 678, lr = 4.78e-03
# 990, train loss = 9.5439e-04, test loss = 2.0114e-02, no improvement for epochs = 688, lr = 4.78e-03
# 1000, train loss = 8.5746e-04, test loss = 2.0367e-02, no improvement for epochs = 698, lr = 4.78e-03
# 1010, train loss = 1.0411e-03, test loss = 2.0755e-02, no improvement for epochs = 708, lr = 4.30e-03
# 1020, train loss = 1.1087e-03, test loss = 2.0269e-02, no improvement for epochs = 718, lr = 4.30e-03
# 1030, train loss = 9.0113e-04, test loss = 2.1323e-02, no improvement for epochs = 728, lr = 4.30e-03
# 1040, train loss = 1.2023e-03, test loss = 2.0670e-02, no improvement for epochs = 738, lr = 4.30e-03
# 1050, train loss = 1.3086e-03, test loss = 2.2219e-02, no improvement for epochs = 748, lr = 4.30e-03
# 1060, train loss = 1.2429e-03, test loss = 1.9513e-02, no improvement for epochs = 758, lr = 4.30e-03
# 1070, train loss = 1.3837e-03, test loss = 2.0620e-02, no improvement for epochs = 768, lr = 4.30e-03
# 1080, train loss = 1.0218e-03, test loss = 2.0963e-02, no improvement for epochs = 778, lr = 4.30e-03
# 1090, train loss = 9.5795e-04, test loss = 2.0807e-02, no improvement for epochs = 788, lr = 4.30e-03
# 1100, train loss = 8.4870e-04, test loss = 1.9925e-02, no improvement for epochs = 798, lr = 4.30e-03
# 1110, train loss = 8.9039e-04, test loss = 2.1110e-02, no improvement for epochs = 808, lr = 3.87e-03
# 1120, train loss = 8.5477e-04, test loss = 2.0829e-02, no improvement for epochs = 818, lr = 3.87e-03
# 1130, train loss = 8.8187e-04, test loss = 2.1981e-02, no improvement for epochs = 828, lr = 3.87e-03
# 1140, train loss = 8.0081e-04, test loss = 2.0982e-02, no improvement for epochs = 838, lr = 3.87e-03
# 1150, train loss = 8.9952e-04, test loss = 2.1354e-02, no improvement for epochs = 848, lr = 3.87e-03
# 1160, train loss = 8.4584e-04, test loss = 2.0284e-02, no improvement for epochs = 858, lr = 3.87e-03
# 1170, train loss = 8.1508e-04, test loss = 2.1185e-02, no improvement for epochs = 868, lr = 3.87e-03
# 1180, train loss = 8.9206e-04, test loss = 2.1455e-02, no improvement for epochs = 878, lr = 3.87e-03
# 1190, train loss = 1.1324e-03, test loss = 2.0286e-02, no improvement for epochs = 888, lr = 3.87e-03
# 1200, train loss = 1.0701e-03, test loss = 2.0170e-02, no improvement for epochs = 898, lr = 3.87e-03
# 1210, train loss = 9.8126e-04, test loss = 1.9806e-02, no improvement for epochs = 908, lr = 3.49e-03
# 1220, train loss = 8.3731e-04, test loss = 2.0660e-02, no improvement for epochs = 918, lr = 3.49e-03
# 1230, train loss = 8.8077e-04, test loss = 1.9380e-02, no improvement for epochs = 928, lr = 3.49e-03
# 1240, train loss = 8.6258e-04, test loss = 1.8456e-02, no improvement for epochs = 938, lr = 3.49e-03
# 1250, train loss = 8.4724e-04, test loss = 1.9994e-02, no improvement for epochs = 948, lr = 3.49e-03
# 1260, train loss = 1.4308e-03, test loss = 1.9727e-02, no improvement for epochs = 958, lr = 3.49e-03
# 1270, train loss = 1.1198e-03, test loss = 2.2187e-02, no improvement for epochs = 968, lr = 3.49e-03
# 1280, train loss = 1.0998e-03, test loss = 2.5750e-02, no improvement for epochs = 978, lr = 3.49e-03
# 1290, train loss = 9.6638e-04, test loss = 2.1810e-02, no improvement for epochs = 988, lr = 3.49e-03
# 1300, train loss = 8.4380e-04, test loss = 2.1450e-02, no improvement for epochs = 998, lr = 3.49e-03
# early stopping activated

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(losses_train, label = 'train')
ax.plot(losses_test, label = 'test')
ax.legend()
ax.set_yscale('log')

# %%
def t2n(x):
    return x.cpu().detach().numpy()


def prep_for_plotting(Y):
    Y = t2n(Y)
    Y, _ = normaize_data(Y, reverse = True, Xnorm = Ynorm)
    Y = Y.squeeze()
    return Y

ya_test = prep_for_plotting(YY_test)
yp_test= prep_for_plotting(YY_pred_test)

ya_train = prep_for_plotting(YY_train)
yp_train= prep_for_plotting(YY_pred_train)



def calculate_error(yp, ya):
    error = yp - ya
    std_error = np.std(error, axis = 0)
    bias_error = np.mean(error, axis = 0)

    return error, std_error, bias_error

error_train, std_error_train, bias_error_train = calculate_error(yp_train, ya_train)
error_test, std_error_test, bias_error_test = calculate_error(yp_test, ya_test)


targets = ['mean P', 'diastolic P', 'systolic P']
fig, ax = plt.subplots(2, N_targets)

for i in range(N_targets):


    ax[0,i].scatter(ya_train[:,i], yp_train[:,i], label = 'train')
    ax[0,i].scatter(ya_test[:,i], yp_test[:,i], label = 'test')
    ax[0,i].plot([np.min(ya_test[:,i]), np.max(ya_test[:,i])], [np.min(ya_test[:,i]), np.max(ya_test[:,i])], color = 'k')
    ax[0,i].legend()


    
    ax[1,i].hist(error_train[:, i], label = f'train, std = {std_error_train[i]:.1f}, bias = {bias_error_train[i]:.1f}', density = True, alpha = 1)
    ax[1,i].hist(error_test[:, i], label = f'test, std = {std_error_test[i]:.1f}, bias = {bias_error_test[i]:.1f} ', density = True, alpha = .6)
    ax[1,i].set_xlabel('error (mmHg)')
    ax[1,i].set_title(f'error historgram: {targets[i]}')
    ax[1,i].legend()


fig.set_size_inches(15, 5)
fig.tight_layout()

# %%
yp.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 yp.shape
#
# NameError: name 'yp' is not defined
